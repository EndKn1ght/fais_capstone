# %% [markdown]
# # Dependencies

# %%
# !pip install tensorflow-text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 88.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-text) (0.13.0)
# Requirement already satisfied: tensorflow<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-text) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.2.2)
# Installing collected packages: tensorflow-text
# Successfully installed tensorflow-text-2.12.1

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import pickle
import re
import tensorflow_hub as hub
import tensorflow_text as text
from sklearn import metrics

# %% [markdown]
# # Data Preparation

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Using dataset: [Gym Exercise Dataset | Kaggle](https://www.kaggle.com/datasets/niharika41298/gym-exercise-data)

# %%
file_path = '/content/gdrive/MyDrive/FAIZ/Dataset/Workout recom/megaGymDataset.csv'

# %%
data = pd.read_csv(file_path)
data.head()
# Out:
#    Unnamed: 0                         Title  \
# 0           0        Partner plank band row
# 1           1  Banded crunch isometric hold
# 2           2         FYR Banded Plank Jack
# 3           3                 Banded crunch
# 4           4                        Crunch
#
#                                                 Desc      Type    BodyPart  \
# 0  The partner plank band row is an abdominal exe...  Strength  Abdominals
# 1  The banded crunch isometric hold is an exercis...  Strength  Abdominals
# 2  The banded plank jack is a variation on the pl...  Strength  Abdominals
# 3  The banded crunch is an exercise targeting the...  Strength  Abdominals
# 4  The crunch is a popular core exercise targetin...  Strength  Abdominals
#
#   Equipment         Level  Rating RatingDesc
# 0     Bands  Intermediate     0.0        NaN
# 1     Bands  Intermediate     NaN        NaN
# 2     Bands  Intermediate     NaN        NaN
# 3     Bands  Intermediate     NaN        NaN
# 4     Bands  Intermediate     NaN        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2918 entries, 0 to 2917
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2918 non-null   int64
#  1   Title       2918 non-null   object
#  2   Desc        1368 non-null   object
#  3   Type        2918 non-null   object
#  4   BodyPart    2918 non-null   object
#  5   Equipment   2918 non-null   object
#  6   Level       2918 non-null   object
#  7   Rating      1031 non-null   float64
#  8   RatingDesc  862 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 205.3+ KB

# %%
# Dropping irrelevant columns
data = data.drop(['Unnamed: 0', 'Rating', 'RatingDesc'], axis=1)

# %%
# Dropping rows with blank description, system will use description to find similarities
data = data.dropna(subset=['Desc'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1368 entries, 0 to 2916
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      1368 non-null   object
#  1   Desc       1368 non-null   object
#  2   Type       1368 non-null   object
#  3   BodyPart   1368 non-null   object
#  4   Equipment  1368 non-null   object
#  5   Level      1368 non-null   object
# dtypes: object(6)
# memory usage: 74.8+ KB

# %%
data.value_counts('Type')
# Out:
# Type
# Strength                 1234
# Plyometrics                53
# Stretching                 44
# Cardio                     17
# Powerlifting               11
# Olympic Weightlifting       5
# Strongman                   4
# dtype: int64

# %%
data.value_counts('BodyPart')
# Out:
# BodyPart
# Abdominals     298
# Quadriceps     245
# Shoulders      174
# Chest          149
# Biceps         101
# Triceps         88
# Lats            69
# Hamstrings      50
# Middle Back     49
# Lower Back      42
# Glutes          29
# Calves          26
# Traps           17
# Forearms        16
# Abductors        8
# Adductors        7
# dtype: int64

# %%
data.value_counts('Equipment')
# Out:
# Equipment
# Body Only        404
# Dumbbell         246
# Barbell          161
# Cable            149
# Machine          121
# Other            101
# Kettlebells       53
# Bands             49
# Exercise Ball     28
# Medicine Ball     25
# E-Z Curl Bar      14
# None               9
# Foam Roll          8
# dtype: int64

# %%
data.value_counts('Level')
# Out:
# Level
# Intermediate    1250
# Beginner         108
# Expert            10
# dtype: int64

# %% [markdown]
# According to the data, system will recommend top 3 alternatives to given workout

# %%
data.loc[data['Equipment'] == 'None']
# Out:
#                                   Title  \
# 637              Decline oblique crunch
# 638                      Decline sit-up
# 639            Hanging Windshield Wiper
# 1402                   Glute ham raise-
# 1403  Lying hamstring stretch with band
# 1406             Alternating lunge jump
# 2421     Dumbbell lateral hop to sprint
# 2422         Smith machine lunge sprint
# 2423                        Sissy squat
#
#                                                    Desc         Type  \
# 637   The decline oblique crunch is a popular bodywe...     Strength
# 638   The decline sit-up is a bodyweight core exerci...     Strength
# 639   The hanging windshield wiper is an advanced ab...     Strength
# 1402  The glute ham raise is an exercise targeting t...     Strength
# 1403  The lying hamstring stretch with band is a sim...   Stretching
# 1406  The alternating lunge jump is an explosive bod...   Stretching
# 2421  The dumbbell lateral hop to sprint is a multi-...  Plyometrics
# 2422  The Smith machine lunge sprint is a lower-body...     Strength
# 2423  The sissy squat is a bodyweight squat variatio...     Strength
#
#         BodyPart Equipment         Level
# 637   Abdominals      None  Intermediate
# 638   Abdominals      None  Intermediate
# 639   Abdominals      None  Intermediate
# 1402  Hamstrings      None      Beginner
# 1403  Hamstrings      None      Beginner
# 1406  Hamstrings      None      Beginner
# 2421  Quadriceps      None  Intermediate
# 2422  Quadriceps      None  Intermediate
# 2423  Quadriceps      None  Intermediate

# %%
data = data.replace('None', "Body Only")

# %%
data.value_counts('Equipment')
# Out:
# Equipment
# Body Only        413
# Dumbbell         246
# Barbell          161
# Cable            149
# Machine          121
# Other            101
# Kettlebells       53
# Bands             49
# Exercise Ball     28
# Medicine Ball     25
# E-Z Curl Bar      14
# Foam Roll          8
# dtype: int64

# %%
# data.to_csv(r'/content/data.csv', index=False, header=True)

# %%
data.isna().sum()
# Out:
# Title        0
# Desc         0
# Type         0
# BodyPart     0
# Equipment    0
# Level        0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 9

# %%
data.loc[data.duplicated(subset=['Title'])]
# Out:
#                                               Title  \
# 97                         Decline bar press sit-up
# 645   Exercise Ball Cable Crunch - Gethin Variation
# 939           Band-suspended kettlebell bench press
# 958           Band-suspended kettlebell bench press
# 1709                              Seated Cable Rows
# 1730                              Seated Cable Rows
# 2004                               Dumbbell step-up
# 2655                                   Arnold press
# 2658                           Seated rear delt fly
#
#                                                    Desc      Type  \
# 97    The decline bar press sit-up is a weighted cor...  Strength
# 645   The exercise ball crunch is a popular gym exer...  Strength
# 939   The band-suspended kettlebell bench press is a...  Strength
# 958   The band-suspended kettlebell bench press is a...  Strength
# 1709  The cable seated row is a popular exercise to ...  Strength
# 1730  The cable seated row is a popular exercise to ...  Strength
# 2004  The dumbbell step-up is a great exercise for b...  Strength
# 2655  Named after the iconic bodybuilder and movie s...  Strength
# 2658  The seated rear delt fly is an upper-body exer...  Strength
#
#          BodyPart Equipment         Level
# 97     Abdominals   Barbell  Intermediate
# 645    Abdominals     Cable  Intermediate
# 939         Chest     Bands  Intermediate
# 958         Chest     Bands  Intermediate
# 1709  Middle Back     Cable  Intermediate
# 1730  Middle Back     Cable  Intermediate
# 2004   Quadriceps  Dumbbell  Intermediate
# 2655    Shoulders  Dumbbell  Intermediate
# 2658    Shoulders  Dumbbell  Intermediate

# %%
# Dropping duplicate workout
data = data.drop_duplicates(subset='Title')

# %%
data = data.reset_index(drop=True)
data
# Out:
#                                        Title  \
# 0                     Partner plank band row
# 1               Banded crunch isometric hold
# 2                      FYR Banded Plank Jack
# 3                              Banded crunch
# 4                                     Crunch
# ...                                      ...
# 1354             Decline EZ-bar skullcrusher
# 1355                     EZ-Bar Skullcrusher
# 1356                    EZ-bar skullcrusher-
# 1357  EZ-Bar Skullcrusher - Gethin Variation
# 1358                        TBS Skullcrusher
#
#                                                    Desc      Type    BodyPart  \
# 0     The partner plank band row is an abdominal exe...  Strength  Abdominals
# 1     The banded crunch isometric hold is an exercis...  Strength  Abdominals
# 2     The banded plank jack is a variation on the pl...  Strength  Abdominals
# 3     The banded crunch is an exercise targeting the...  Strength  Abdominals
# 4     The crunch is a popular core exercise targetin...  Strength  Abdominals
# ...                                                 ...       ...         ...
# 1354  The decline EZ-bar skullcrusher is a popular e...  Strength     Triceps
# 1355  The EZ-bar skullcrusher is a popular exercise ...  Strength     Triceps
# 1356  The EZ-bar skullcrusher is a popular exercise ...  Strength     Triceps
# 1357  The EZ-bar skullcrusher is a popular exercise ...  Strength     Triceps
# 1358  The EZ-bar skullcrusher is a popular exercise ...  Strength     Triceps
#
#          Equipment         Level
# 0            Bands  Intermediate
# 1            Bands  Intermediate
# 2            Bands  Intermediate
# 3            Bands  Intermediate
# 4            Bands  Intermediate
# ...            ...           ...
# 1354  E-Z Curl Bar  Intermediate
# 1355  E-Z Curl Bar  Intermediate
# 1356  E-Z Curl Bar  Intermediate
# 1357  E-Z Curl Bar  Intermediate
# 1358  E-Z Curl Bar  Intermediate
#
# [1359 rows x 6 columns]

# %%
data['Title'] = data['Title'].apply(lambda x: re.sub('[^A-Za-z0-9]+', ' ', x))

# %%
data['Title'] = data['Title'].apply(lambda x: x.lower())

# %%
data['Title'] = data['Title'].apply(lambda x: x.strip())

# %%
data.loc[data.duplicated(subset=['Title'])]
# Out:
#                                      Title  \
# 35                dumbbell v sit cross jab
# 199                         decline crunch
# 232                                otis up
# 328                           barbell curl
# 437                    standing calf raise
# 477                  push up to side plank
# 517      smith machine incline bench press
# 557                   dumbbell bench press
# 623                     barbell hip thrust
# 675                        glute ham raise
# 704          standing dumbbell knee crunch
# 757                       barbell deadlift
# 786                               superman
# 808              single arm kettlebell row
# 820    alternating sit through with crunch
# 853                        machine low row
# 921                           goblet squat
# 923                  dumbbell goblet squat
# 957                              sled push
# 961                 dumbbell walking lunge
# 983                              leg press
# 986                       seated leg press
# 992                             hack squat
# 1035                          jumping jack
# 1059                            jump squat
# 1131   single arm incline cable cross over
# 1144          double kettlebell push press
# 1334             machine triceps extension
# 1337  smith machine close grip bench press
# 1356                   ez bar skullcrusher
#
#                                                    Desc       Type  \
# 35    The dumbbell V-sit cross jab is a hybrid movem...   Strength
# 199   The decline crunch is a popular bodyweight exe...   Strength
# 232   The Otis-up is a weighted exercise focusing on...   Strength
# 328   The barbell curl is an arm exercise that is al...   Strength
# 437   The standing calf raise is a popular movement ...   Strength
# 477   The push-up to side plank is an upper-body and...   Strength
# 517   The Smith machine incline bench press is a mac...   Strength
# 557   The dumbbell bench press is a mainstay of lift...   Strength
# 623   The barbell hip thrust is a popular exercise t...   Strength
# 675   The glute ham raise is an exercise targeting t...   Strength
# 704   The standing dumbbell knee crunch is a great w...   Strength
# 757   The barbell deadlift is a compound exercise us...   Strength
# 786   The Superman is a bodyweight exercise that con...   Strength
# 808   The single-arm kettlebell row is a popular mus...   Strength
# 820   The alternating sit-through with crunch is a f...   Strength
# 853   The machine low row is a popular exercise targ...   Strength
# 921   The goblet squat is a popular lower-body exerc...   Strength
# 923   The goblet squat is a common exercise used in ...   Strength
# 957   The sled push is a conditioning exercise that ...  Strongman
# 961   The dumbbell walking lunge is a popular lower-...   Strength
# 983   The leg press is a machine exercise targeting ...   Strength
# 986   The seated leg press is a machine-based exerci...   Strength
# 992   The hack squat is a machine-based exercise tha...   Strength
# 1035  The jumping jack is a classic calisthenics exe...     Cardio
# 1059  The jump squat is an explosive bodyweight exer...   Strength
# 1131  The single-arm incline cable cross-over is an ...   Strength
# 1144  The double-kettlebell push-press is a popular ...   Strength
# 1334  The machine triceps extension is an isolation ...   Strength
# 1337  The Smith machine close-grip bench press is a ...   Strength
# 1356  The EZ-bar skullcrusher is a popular exercise ...   Strength
#
#          BodyPart     Equipment         Level
# 35     Abdominals      Dumbbell  Intermediate
# 199    Abdominals     Body Only  Intermediate
# 232    Abdominals     Body Only  Intermediate
# 328        Biceps       Barbell  Intermediate
# 437        Calves     Body Only  Intermediate
# 477         Chest     Body Only  Intermediate
# 517         Chest       Machine  Intermediate
# 557         Chest      Dumbbell  Intermediate
# 623        Glutes     Body Only  Intermediate
# 675    Hamstrings     Body Only      Beginner
# 704          Lats         Other  Intermediate
# 757    Lower Back       Barbell  Intermediate
# 786    Lower Back     Body Only  Intermediate
# 808   Middle Back   Kettlebells  Intermediate
# 820   Middle Back         Other  Intermediate
# 853         Traps       Machine  Intermediate
# 921    Quadriceps   Kettlebells  Intermediate
# 923    Quadriceps      Dumbbell  Intermediate
# 957    Quadriceps         Other  Intermediate
# 961    Quadriceps         Other  Intermediate
# 983    Quadriceps       Machine  Intermediate
# 986    Quadriceps       Machine  Intermediate
# 992    Quadriceps       Machine  Intermediate
# 1035   Quadriceps     Body Only  Intermediate
# 1059   Quadriceps     Body Only  Intermediate
# 1131    Shoulders       Barbell  Intermediate
# 1144    Shoulders   Kettlebells  Intermediate
# 1334      Triceps       Machine  Intermediate
# 1337      Triceps       Machine  Intermediate
# 1356      Triceps  E-Z Curl Bar  Intermediate

# %%
# Dropping duplicate workout
data = data.drop_duplicates(subset='Title')

# %%
data = data.reset_index(drop=True)
data
# Out:
#                                      Title  \
# 0                   partner plank band row
# 1             banded crunch isometric hold
# 2                    fyr banded plank jack
# 3                            banded crunch
# 4                                   crunch
# ...                                    ...
# 1324                             bench dip
# 1325           decline ez bar skullcrusher
# 1326                   ez bar skullcrusher
# 1327  ez bar skullcrusher gethin variation
# 1328                      tbs skullcrusher
#
#                                                    Desc      Type    BodyPart  \
# 0     The partner plank band row is an abdominal exe...  Strength  Abdominals
# 1     The banded crunch isometric hold is an exercis...  Strength  Abdominals
# 2     The banded plank jack is a variation on the pl...  Strength  Abdominals
# 3     The banded crunch is an exercise targeting the...  Strength  Abdominals
# 4     The crunch is a popular core exercise targetin...  Strength  Abdominals
# ...                                                 ...       ...         ...
# 1324  The bench dip is a highly effective exercise f...  Strength     Triceps
# 1325  The decline EZ-bar skullcrusher is a popular e...  Strength     Triceps
# 1326  The EZ-bar skullcrusher is a popular exercise ...  Strength     Triceps
# 1327  The EZ-bar skullcrusher is a popular exercise ...  Strength     Triceps
# 1328  The EZ-bar skullcrusher is a popular exercise ...  Strength     Triceps
#
#          Equipment         Level
# 0            Bands  Intermediate
# 1            Bands  Intermediate
# 2            Bands  Intermediate
# 3            Bands  Intermediate
# 4            Bands  Intermediate
# ...            ...           ...
# 1324     Body Only  Intermediate
# 1325  E-Z Curl Bar  Intermediate
# 1326  E-Z Curl Bar  Intermediate
# 1327  E-Z Curl Bar  Intermediate
# 1328  E-Z Curl Bar  Intermediate
#
# [1329 rows x 6 columns]

# %%
data.to_csv(r'/content/workout_dataset.csv', index=True, header=True)

# %% [markdown]
# # Modeling

# %%
new_data = data

# %%
# Normalizing description feature
new_data['Desc'] = data['Desc'].apply(lambda x: x.lower())
new_data['Desc'] = new_data['Desc'].apply(lambda x: re.sub('[^A-Za-z0-9]+', ' ', x))

# %%
new_data.head()
# Out:
#                           Title  \
# 0        partner plank band row
# 1  banded crunch isometric hold
# 2         fyr banded plank jack
# 3                 banded crunch
# 4                        crunch
#
#                                                 Desc      Type    BodyPart  \
# 0  the partner plank band row is an abdominal exe...  Strength  Abdominals
# 1  the banded crunch isometric hold is an exercis...  Strength  Abdominals
# 2  the banded plank jack is a variation on the pl...  Strength  Abdominals
# 3  the banded crunch is an exercise targeting the...  Strength  Abdominals
# 4  the crunch is a popular core exercise targetin...  Strength  Abdominals
#
#   Equipment         Level
# 0     Bands  Intermediate
# 1     Bands  Intermediate
# 2     Bands  Intermediate
# 3     Bands  Intermediate
# 4     Bands  Intermediate

# %%
encoded_data = new_data

# %%
# Using BERT to encode description text
preprocessor = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4", trainable=True)

def get_bert_embeddings(text, preprocessor, encoder):
  text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
  encoder_inputs = preprocessor(text_input)
  outputs = encoder(encoder_inputs)
  embedding_model = tf.keras.Model(text_input, outputs['pooled_output'])
  sentences = tf.constant([text])
  return embedding_model(sentences)

encoded_data['encodings'] = encoded_data['Desc'].apply(lambda x: get_bert_embeddings(x, preprocessor, encoder))

# %%
encoded_data
# Out:
#                                      Title  \
# 0                   partner plank band row
# 1             banded crunch isometric hold
# 2                    fyr banded plank jack
# 3                            banded crunch
# 4                                   crunch
# ...                                    ...
# 1324                             bench dip
# 1325           decline ez bar skullcrusher
# 1326                   ez bar skullcrusher
# 1327  ez bar skullcrusher gethin variation
# 1328                      tbs skullcrusher
#
#                                                    Desc      Type    BodyPart  \
# 0     the partner plank band row is an abdominal exe...  Strength  Abdominals
# 1     the banded crunch isometric hold is an exercis...  Strength  Abdominals
# 2     the banded plank jack is a variation on the pl...  Strength  Abdominals
# 3     the banded crunch is an exercise targeting the...  Strength  Abdominals
# 4     the crunch is a popular core exercise targetin...  Strength  Abdominals
# ...                                                 ...       ...         ...
# 1324  the bench dip is a highly effective exercise f...  Strength     Triceps
# 1325  the decline ez bar skullcrusher is a popular e...  Strength     Triceps
# 1326  the ez bar skullcrusher is a popular exercise ...  Strength     Triceps
# 1327  the ez bar skullcrusher is a popular exercise ...  Strength     Triceps
# 1328  the ez bar skullcrusher is a popular exercise ...  Strength     Triceps
#
#          Equipment         Level  \
# 0            Bands  Intermediate
# 1            Bands  Intermediate
# 2            Bands  Intermediate
# 3            Bands  Intermediate
# 4            Bands  Intermediate
# ...            ...           ...
# 1324     Body Only  Intermediate
# 1325  E-Z Curl Bar  Intermediate
# 1326  E-Z Curl Bar  Intermediate
# 1327  E-Z Curl Bar  Intermediate
# 1328  E-Z Curl Bar  Intermediate
#
#                                               encodings
# 0     ((tf.Tensor(-0.497315, shape=(), dtype=float32...
# 1     ((tf.Tensor(-0.6131973, shape=(), dtype=float3...
# 2     ((tf.Tensor(-0.6472458, shape=(), dtype=float3...
# 3     ((tf.Tensor(-0.6446581, shape=(), dtype=float3...
# 4     ((tf.Tensor(-0.62150997, shape=(), dtype=float...
# ...                                                 ...
# 1324  ((tf.Tensor(-0.76620835, shape=(), dtype=float...
# 1325  ((tf.Tensor(-0.26601514, shape=(), dtype=float...
# 1326  ((tf.Tensor(-0.73581356, shape=(), dtype=float...
# 1327  ((tf.Tensor(-0.73581356, shape=(), dtype=float...
# 1328  ((tf.Tensor(-0.73581356, shape=(), dtype=float...
#
# [1329 rows x 7 columns]

# %%
encodings = encoded_data['encodings']
encodings
# Out:
# 0       ((tf.Tensor(-0.497315, shape=(), dtype=float32...
# 1       ((tf.Tensor(-0.6131973, shape=(), dtype=float3...
# 2       ((tf.Tensor(-0.6472458, shape=(), dtype=float3...
# 3       ((tf.Tensor(-0.6446581, shape=(), dtype=float3...
# 4       ((tf.Tensor(-0.62150997, shape=(), dtype=float...
#                               ...
# 1324    ((tf.Tensor(-0.76620835, shape=(), dtype=float...
# 1325    ((tf.Tensor(-0.26601514, shape=(), dtype=float...
# 1326    ((tf.Tensor(-0.73581356, shape=(), dtype=float...
# 1327    ((tf.Tensor(-0.73581356, shape=(), dtype=float...
# 1328    ((tf.Tensor(-0.73581356, shape=(), dtype=float...
# Name: encodings, Length: 1329, dtype: object

# %%
encodings.to_json('encodings.json', default_handler=str)

# %%
with open('encodings.pickle', 'wb') as pkl:
  pickle.dump(encodings, pkl)

# %% [markdown]
# # Retrieving recommendations

# %%
# Take one workout sample
sample_input = new_data.sample()
sample_input

# %%
query_text = sample_input.iat[0, 1]
print(query_text)

# %%
query_encoding = get_bert_embeddings(query_text, preprocessor, encoder)

# Calculating cosine similarity
encoded_data['similarity_score'] = encoded_data['encodings'].apply(lambda x: metrics.pairwise.cosine_similarity(x, query_encoding)[0][0])
results = encoded_data.sort_values(by=['similarity_score'], ascending=False)

# %%
# Returning top 3 recommendation
top3 = results.iloc[1:4]
top3 = top3.drop('encodings', axis=1)
top3

# %%
def give_recommendation(text: str) -> int:

# %% [markdown]
# # Evaluation

# %%
def eval(index):
  # Taking a row from workout data
  sample_input = new_data.iloc[[index]]
  query_text = sample_input.iat[0, 1]
  query_encoding = get_bert_embeddings(query_text, preprocessor, encoder)

  # Calculating similarity
  encoded_data['similarity_score'] = encoded_data['encodings'].apply(lambda x: metrics.pairwise.cosine_similarity(x, query_encoding)[0][0])
  results = encoded_data.sort_values(by=['similarity_score'], ascending=False)

  # Returning top 3 recommendation
  top3 = results.iloc[1:4]
  top3 = top3.drop('encodings', axis=1)

  # Normalizing input dataframe
  sample_input = sample_input.drop('encodings', axis=1)
  sample_input = sample_input.reset_index(drop=True)
  sample_input = pd.concat([sample_input]*3, ignore_index=True)

  # Normalizing output dataframe
  top3 = top3.reset_index(drop=True)
  top3 = top3.drop('similarity_score', axis=1)

  # Calculating precision
  top3['type_precision'] = np.where(sample_input['Type'] == top3['Type'], 1, 0)
  top3['body_precision'] = np.where(sample_input['BodyPart'] == top3['BodyPart'], 1, 0)
  top3['equipment_precision'] = np.where(sample_input['Equipment'] == top3['Equipment'], 1, 0)
  top3['level_precision'] = np.where(sample_input['Level'] == top3['Level'], 1, 0)
  precision = (top3['type_precision'].sum() + top3['body_precision'].sum() + top3['equipment_precision'].sum() + top3['level_precision'].sum())/12
  return precision

# %%
# Iterating through all rows of data to calculate system precision
all_precision = []
for i in range(len(new_data.index)):
  precision = eval(i)
  all_precision.append(precision)
mean_precision = sum(all_precision) / len(all_precision)
print('System precision:', "{:.0%}".format(mean_precision))
