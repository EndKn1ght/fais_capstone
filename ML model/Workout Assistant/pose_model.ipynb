# %% [markdown]
# # **Imports and Dependencies**

# %%
import tensorflow as tf
import tensorflow_hub as hub
from keras.layers import Input, Flatten, Dense, Dropout
from keras.models import Model
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2

# %%
KEYPOINT_EDGES = [
    (0, 1),
    (0, 2),
    (1, 3),
    (2, 4),
    (0, 5),
    (0, 6),
    (5, 7),
    (7, 9),
    (6, 8),
    (8, 10),
    (5, 6),
    (5, 11),
    (6, 12),
    (11, 12),
    (11, 13),
    (13, 15),
    (12, 14),
    (14, 16)
]

# %% [markdown]
# # **Data Preprocessing**

# %%
df = pd.read_csv("keypoints_data.csv")
df.head()
# Out:
#       noseX     noseY  left_eyeX  left_eyeY  right_eyeX  right_eyeY  \
# 0  0.539241  0.562888   0.555527   0.561902    0.529999    0.558287
# 1  0.256339  0.555525   0.245591   0.542631    0.246213    0.538990
# 2  0.539357  0.690845   0.555154   0.703071    0.523741    0.697469
# 3  0.543826  0.776397   0.563946   0.782749    0.533213    0.780279
# 4  0.543992  0.780590   0.560737   0.788503    0.530577    0.787271
#
#    left_earX  left_earY  right_earX  right_earY  ...  right_hipY  left_kneeX  \
# 0   0.574060   0.531854    0.502490    0.526930  ...    0.421526    0.608265
# 1   0.251576   0.498928    0.248534    0.489597  ...    0.483305    0.768328
# 2   0.579763   0.676099    0.498116    0.666432  ...    0.470383    0.576357
# 3   0.588520   0.754564    0.501276    0.742542  ...    0.522356    0.537980
# 4   0.587577   0.760645    0.496612    0.746140  ...    0.519301    0.548825
#
#    left_kneeY  right_kneeX  right_kneeY  left_ankleX  left_ankleY  \
# 0    0.571625     0.495987     0.584337     0.537182     0.693354
# 1    0.639089     0.774396     0.621811     0.948640     0.739688
# 2    0.609860     0.473827     0.595566     0.537077     0.705968
# 3    0.573046     0.482752     0.574605     0.683411     0.762736
# 4    0.568235     0.461435     0.600380     0.540867     0.599851
#
#    right_ankleX  right_ankleY  exercise
# 0      0.515442      0.694399         0
# 1      0.940743      0.726468         0
# 2      0.435812      0.735543         0
# 3      0.402634      0.757211         0
# 4      0.502858      0.617974         0
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1343 entries, 0 to 1342
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   noseX            1343 non-null   float64
#  1   noseY            1343 non-null   float64
#  2   left_eyeX        1343 non-null   float64
#  3   left_eyeY        1343 non-null   float64
#  4   right_eyeX       1343 non-null   float64
#  5   right_eyeY       1343 non-null   float64
#  6   left_earX        1343 non-null   float64
#  7   left_earY        1343 non-null   float64
#  8   right_earX       1343 non-null   float64
#  9   right_earY       1343 non-null   float64
#  10  left_shoulderX   1343 non-null   float64
#  11  left_shoulderY   1343 non-null   float64
#  12  right_shoulderX  1343 non-null   float64
#  13  right_shoulderY  1343 non-null   float64
#  14  left_elbowX      1343 non-null   float64
#  15  left_elbowY      1343 non-null   float64
#  16  right_elbowX     1343 non-null   float64
#  17  right_elbowY     1343 non-null   float64
#  18  left_wristX      1343 non-null   float64
#  19  left_wristY      1343 non-null   float64
#  20  right_wristX     1343 non-null   float64
#  21  right_wristY     1343 non-null   float64
#  22  left_hipX        1343 non-null   float64
#  23  left_hipY        1343 non-null   float64
#  24  right_hipX       1343 non-null   float64
#  25  right_hipY       1343 non-null   float64
#  26  left_kneeX       1343 non-null   float64
#  27  left_kneeY       1343 non-null   float64
#  28  right_kneeX      1343 non-null   float64
#  29  right_kneeY      1343 non-null   float64
#  30  left_ankleX      1343 non-null   float64
#  31  left_ankleY      1343 non-null   float64
#  32  right_ankleX     1343 non-null   float64
#  33  right_ankleY     1343 non-null   float64
#  34  exercise         1343 non-null   int64
# dtypes: float64(34), int64(1)
# memory usage: 367.4 KB

# %% [markdown]
# Split dataset into train and validation sets

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state=420)

print(X_train)
print(y_train)
print(X_val)
print(y_val)
# Out:
#          noseX     noseY  left_eyeX  left_eyeY  right_eyeX  right_eyeY  \
# 715   0.470746  0.365668   0.473252   0.352121    0.467526    0.354558
# 1039  0.498495  0.232756   0.496011   0.219038    0.494417    0.219626
# 356   0.292468  0.412111   0.291213   0.388220    0.289374    0.394430
# 307   0.725959  0.417009   0.734201   0.407230    0.728970    0.398214
# 472   0.526853  0.763519   0.508584   0.765417    0.561460    0.749324
# ...        ...       ...        ...        ...         ...         ...
# 799   0.396391  0.380018   0.404836   0.360707    0.393653    0.363077
# 575   0.264159  0.528631   0.248735   0.517414    0.246885    0.514527
# 390   0.197454  0.521350   0.199203   0.496156    0.192287    0.497687
# 1096  0.455318  0.217407   0.476576   0.200662    0.429020    0.201641
# 945   0.500824  0.178994   0.517378   0.160789    0.487140    0.161537
#
#       left_earX  left_earY  right_earX  right_earY  ...  right_hipX  \
# 715    0.494753   0.349287    0.476160    0.349746  ...    0.513433
# 1039   0.492210   0.214319    0.490772    0.214905  ...    0.493964
# 356    0.333628   0.345229    0.319189    0.360960  ...    0.552320
# 307    0.707043   0.360221    0.698084    0.339274  ...    0.406808
# 472    0.461760   0.732173    0.608808    0.706800  ...    0.589231
# ...         ...        ...         ...         ...  ...         ...
# 799    0.453607   0.339487    0.424288    0.341373  ...    0.453022
# 575    0.252581   0.479082    0.254628    0.471344  ...    0.571141
# 390    0.252396   0.450084    0.230962    0.454618  ...    0.596801
# 1096   0.501830   0.240290    0.395317    0.242399  ...    0.379168
# 945    0.538160   0.165488    0.470987    0.170328  ...    0.461070
#
#       right_hipY  left_kneeX  left_kneeY  right_kneeX  right_kneeY  \
# 715     0.547074    0.507397    0.631380     0.488429     0.632135
# 1039    0.479149    0.497547    0.625627     0.493649     0.633563
# 356     0.552773    0.717406    0.647133     0.697621     0.656829
# 307     0.490067    0.291588    0.645934     0.252984     0.640704
# 472     0.651738    0.372830    0.604777     0.665614     0.598804
# ...          ...         ...         ...          ...          ...
# 799     0.617314    0.482752    0.800810     0.430147     0.772565
# 575     0.510801    0.752844    0.643917     0.764315     0.616070
# 390     0.527008    0.789558    0.606752     0.739145     0.594256
# 1096    0.776901    0.572936    0.874462     0.349797     0.903318
# 945     0.468917    0.590150    0.582419     0.414804     0.573902
#
#       left_ankleX  left_ankleY  right_ankleX  right_ankleY
# 715      0.522262     0.705520      0.521058      0.699990
# 1039     0.487005     0.771318      0.486422      0.776728
# 356      0.849487     0.743896      0.821557      0.735134
# 307      0.139505     0.745887      0.111927      0.759484
# 472      0.379643     0.680515      0.623992      0.655391
# ...           ...          ...           ...           ...
# 799      0.502480     0.873739      0.456167      0.862051
# 575      0.938058     0.725189      0.934049      0.708136
# 390      0.919991     0.626610      0.860440      0.616183
# 1096     0.667564     0.419188      0.370664      0.854384
# 945      0.572073     0.765574      0.441559      0.766194
#
# [1074 rows x 34 columns]
# 715     1
# 1039    1
# 356     0
# 307     0
# 472     0
#        ..
# 799     1
# 575     0
# 390     0
# 1096    1
# 945     1
# Name: exercise, Length: 1074, dtype: int64
#          noseX     noseY  left_eyeX  left_eyeY  right_eyeX  right_eyeY  \
# 285   0.566898  0.835025   0.595446   0.818906    0.548341    0.817301
# 989   0.793294  0.251404   0.788088   0.240723    0.787796    0.241735
# 336   0.689405  0.405558   0.705666   0.378258    0.672319    0.382745
# 159   0.448290  0.229174   0.477186   0.192710    0.419602    0.193569
# 767   0.443999  0.233985   0.452089   0.220390    0.430552    0.222209
# ...        ...       ...        ...        ...         ...         ...
# 440   0.246976  0.467691   0.265873   0.444926    0.235866    0.448800
# 1195  0.551764  0.396841   0.558643   0.382382    0.542524    0.382985
# 341   0.689985  0.401692   0.707909   0.377074    0.676699    0.380222
# 936   0.498891  0.095823   0.508731   0.035207    0.493116    0.090417
# 1033  0.478415  0.487979   0.487109   0.473114    0.468672    0.474866
#
#       left_earX  left_earY  right_earX  right_earY  ...  right_hipX  \
# 285    0.625643   0.758880    0.494810    0.758106  ...    0.317794
# 989    0.764480   0.236005    0.764135    0.238903  ...    0.695958
# 336    0.735081   0.370813    0.659078    0.379130  ...    0.665524
# 159    0.520570   0.199889    0.389153    0.203375  ...    0.443567
# 767    0.466157   0.230475    0.416127    0.233215  ...    0.407014
# ...         ...        ...         ...         ...  ...         ...
# 440    0.291842   0.395678    0.204663    0.400510  ...    0.222646
# 1195   0.557230   0.365334    0.510997    0.362560  ...    0.453510
# 341    0.740465   0.374750    0.671109    0.379498  ...    0.668630
# 936    0.526095   0.062879    0.476019    0.055982  ...    0.461226
# 1033   0.500856   0.470815    0.464154    0.476000  ...    0.460978
#
#       right_hipY  left_kneeX  left_kneeY  right_kneeX  right_kneeY  \
# 285     0.538433    0.349594    0.546762     0.247868     0.607225
# 989     0.490923    0.723092    0.632349     0.718851     0.633845
# 336     0.636358    0.847888    0.500946     0.679338     0.598760
# 159     0.582764    0.554247    0.633585     0.432031     0.640033
# 767     0.488136    0.493080    0.659553     0.394397     0.659118
# ...          ...         ...         ...          ...          ...
# 440     0.580128    0.310763    0.609232     0.215633     0.603743
# 1195    0.632693    0.524262    0.778713     0.473144     0.796138
# 341     0.657783    0.850907    0.504339     0.679115     0.623320
# 936     0.366947    0.578269    0.563284     0.439762     0.554253
# 1033    0.679475    0.534962    0.681724     0.517425     0.685245
#
#       left_ankleX  left_ankleY  right_ankleX  right_ankleY
# 285      0.267933     0.545432      0.180249      0.551661
# 989      0.698381     0.765219      0.697207      0.776598
# 336      0.777995     0.754426      0.633356      0.779615
# 159      0.544286     0.532952      0.478344      0.533648
# 767      0.495712     0.814521      0.380783      0.815090
# ...           ...          ...           ...           ...
# 440      0.279342     0.668875      0.245229      0.655602
# 1195     0.518142     0.882028      0.478837      0.880192
# 341      0.770171     0.725266      0.702327      0.752782
# 936      0.572116     0.761088      0.441361      0.764507
# 1033     0.506354     0.792090      0.482538      0.788646
#
# [269 rows x 34 columns]
# 285     0
# 989     1
# 336     0
# 159     0
# 767     1
#        ..
# 440     0
# 1195    1
# 341     0
# 936     1
# 1033    1
# Name: exercise, Length: 269, dtype: int64

# %% [markdown]
# # **Initialize the Base Model (in consideration of improving the model later on)**

# %%
def base_model():
  input = Input(shape=(34,), name="base_input")
  x = Flatten()(input)
  x = Dense(128, activation="relu", name="first_dense")(x)
  x = Dropout(0.3)(x)
  x = Dense(64, activation="relu", name="second_dense")(x)
  x = Dropout(0.2)(x)
  x = Dense(32, activation="relu", name="third_dense")(x)
  x = Dropout(0.1)(x)
  x = Dense(1, activation="sigmoid", name="base_output")(x)
  return Model(inputs=input, outputs=x)

# %% [markdown]
# Plot the model

# %%
model = base_model()
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, to_file='base-model.png')

# %% [markdown]
# Compile and train the model

# %%
model.compile(
    optimizer = "adam", 
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
  )

model.summary()

history = model.fit(
    X_train, 
    y_train, 
    batch_size=32,
    epochs=50, 
    validation_data=(X_val, y_val)
    )
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  base_input (InputLayer)     [(None, 34)]              0
#
#  flatten_2 (Flatten)         (None, 34)                0
#
#  first_dense (Dense)         (None, 128)               4480
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  second_dense (Dense)        (None, 64)                8256
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  third_dense (Dense)         (None, 32)                2080
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  base_output (Dense)         (None, 1)                 33
#
# =================================================================
# Total params: 14,849
# Trainable params: 14,849
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 34/34 [==============================] - 1s 9ms/step - loss: 0.6486 - accuracy: 0.6331 - val_loss: 0.5317 - val_accuracy: 0.8810
# Epoch 2/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.8529 - val_loss: 0.2323 - val_accuracy: 0.9665
# Epoch 3/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.2632 - accuracy: 0.9153 - val_loss: 0.1227 - val_accuracy: 0.9665
# Epoch 4/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.1439 - accuracy: 0.9646 - val_loss: 0.0833 - val_accuracy: 0.9888
# Epoch 5/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.1104 - accuracy: 0.9674 - val_loss: 0.0681 - val_accuracy: 0.9888
# Epoch 6/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0934 - accuracy: 0.9739 - val_loss: 0.0636 - val_accuracy: 0.9888
# Epoch 7/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0757 - accuracy: 0.9804 - val_loss: 0.0571 - val_accuracy: 0.9926
# Epoch 8/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0645 - accuracy: 0.9842 - val_loss: 0.0612 - val_accuracy: 0.9888
# Epoch 9/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0742 - accuracy: 0.9739 - val_loss: 0.1022 - val_accuracy: 0.9740
# Epoch 10/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0658 - accuracy: 0.9823 - val_loss: 0.0515 - val_accuracy: 0.9888
# Epoch 11/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0627 - accuracy: 0.9832 - val_loss: 0.0467 - val_accuracy: 0.9888
# Epoch 12/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0522 - accuracy: 0.9860 - val_loss: 0.0371 - val_accuracy: 0.9926
# Epoch 13/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0504 - accuracy: 0.9851 - val_loss: 0.0495 - val_accuracy: 0.9888
# Epoch 14/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0472 - accuracy: 0.9851 - val_loss: 0.0335 - val_accuracy: 0.9926
# Epoch 15/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0401 - accuracy: 0.9842 - val_loss: 0.0358 - val_accuracy: 0.9926
# Epoch 16/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0414 - accuracy: 0.9870 - val_loss: 0.0246 - val_accuracy: 0.9926
# Epoch 17/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0403 - accuracy: 0.9851 - val_loss: 0.0375 - val_accuracy: 0.9888
# Epoch 18/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0398 - accuracy: 0.9870 - val_loss: 0.0234 - val_accuracy: 0.9926
# Epoch 19/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0410 - accuracy: 0.9851 - val_loss: 0.0176 - val_accuracy: 0.9963
# Epoch 20/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9907 - val_loss: 0.0169 - val_accuracy: 0.9926
# Epoch 21/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.0110 - val_accuracy: 0.9963
# Epoch 22/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 0.0109 - val_accuracy: 0.9963
# Epoch 23/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 0.9963 - val_loss: 0.0207 - val_accuracy: 0.9926
# Epoch 24/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0226 - accuracy: 0.9944 - val_loss: 0.0087 - val_accuracy: 0.9963
# Epoch 25/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0244 - accuracy: 0.9898 - val_loss: 0.0330 - val_accuracy: 0.9851
# Epoch 26/50
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 0.9926 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 27/50
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 0.9898 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 28/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9888 - val_loss: 0.0085 - val_accuracy: 0.9963
# Epoch 29/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 30/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9953 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 31/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9879 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 32/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 0.9907 - val_loss: 0.0137 - val_accuracy: 0.9926
# Epoch 33/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9963 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 34/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0360 - accuracy: 0.9870 - val_loss: 0.0138 - val_accuracy: 0.9926
# Epoch 35/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9981 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 36/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.0070 - val_accuracy: 0.9963
# Epoch 37/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 0.9926 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 38/50
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 0.9944 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 39/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 40/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9981 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 41/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9953 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 42/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0278 - accuracy: 0.9888 - val_loss: 0.0181 - val_accuracy: 0.9926
# Epoch 43/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 44/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9963 - val_loss: 0.0052 - val_accuracy: 0.9963
# Epoch 45/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9953 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 46/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9926 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 47/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9972 - val_loss: 0.0061 - val_accuracy: 0.9963
# Epoch 48/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9898 - val_loss: 0.0318 - val_accuracy: 0.9888
# Epoch 49/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9842 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 50/50
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0252 - accuracy: 0.9916 - val_loss: 0.0048 - val_accuracy: 1.0000

# %% [markdown]
# Plot the accuracy per epoch

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %%
plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %% [markdown]
# # **Start Predicting Real Keypoints From Images**

# %% [markdown]
# Load MoveNet Lightning Model

# %%
movenet_model = hub.load("https://tfhub.dev/google/movenet/singlepose/lightning/4")

# %%
def predict_keypoints(model, image_path):
    # Read image files and rersize it to 192x192
    image = tf.io.read_file(image_path)
    image = tf.compat.v1.image.decode_jpeg(image)
    image = tf.expand_dims(image, axis=0)
    image = tf.cast(tf.image.resize_with_pad(image, 192, 192), dtype=tf.int32)

    # Predict using movenet
    movenet = model.signatures["serving_default"]
    outputs = movenet(image)

    # Return keypoints in (1, 1, 17, 3)
    keypoints = outputs["output_0"]

    return image, keypoints

# %% [markdown]
# Display Keypoints

# %%
from google.colab.patches import cv2_imshow

def display_keypoints(input_image, keypoints, width=512, height=512):
    input_image = tf.image.resize_with_pad(input_image, width, height)
    input_image = tf.cast(input_image, dtype=tf.uint8)

    npy_image = np.squeeze(input_image.numpy(), axis=0)
    npy_image = cv2.resize(npy_image, (width, height))
    npy_image = cv2.cvtColor(npy_image, cv2.COLOR_RGB2BGR)

    for keypoint in keypoints[0][0]:
        x = int(keypoint[1] * width)
        y = int(keypoint[0] * height)
        cv2.circle(npy_image, (x, y), 4, (0, 255, 255), -1)

    for edge in KEYPOINT_EDGES:
        x1 = int(keypoints[0][0][edge[0]][1] * width)
        y1 = int(keypoints[0][0][edge[0]][0] * height)
        x2 = int(keypoints[0][0][edge[1]][1] * width)
        y2 = int(keypoints[0][0][edge[1]][0] * height)
        cv2.line(npy_image, (x1, y1), (x2, y2), (255, 0, 0), 2)

    cv2_imshow(npy_image)
    cv2.waitKey()

# %% [markdown]
# ### **if 1 = squat and if 0 = pushup**

# %% [markdown]
# Predict pushup and squat images

# %%
image_data = [
    "pushup1.jpg",
    "pushup2.jpg",
    "squat1.jpg",
    "squat2.jpg"
    ]

# %%
for img in image_data:
  input_image, keypoints = predict_keypoints(movenet_model, img)
  data_temp = []
  for keypoint in keypoints[0][0]:
            x = float(keypoint[1].numpy())
            y = float(keypoint[0].numpy())
            data_temp.append(x)
            data_temp.append(y)

  display_keypoints(input_image, keypoints, 400, 400)

  # Predict pose according to keypoints data
  data_temp = tf.reshape(data_temp, shape=(-1, 34))
  predick = model.predict(data_temp)
  print("anjay squat ({})".format(predick) if predick > 0.5 else "pushup gan ({})\n".format(predick))
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F28FCD5BE50>
# 1/1 [==============================] - 0s 60ms/step
# pushup gan ([[3.507175e-05]])
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F28FD4A4280>
# 1/1 [==============================] - 0s 23ms/step
# pushup gan ([[0.00017874]])
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F2901EC0610>
# 1/1 [==============================] - 0s 23ms/step
# anjay squat ([[0.9985604]])
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F2901EC0610>
# 1/1 [==============================] - 0s 25ms/step
# anjay squat ([[0.99898356]])

# %% [markdown]
# # **Save Model**

# %%
tf.saved_model.save(model, "pose_esti1")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
